# %%
import pandas as pd 
df  = pd.read_csv('../data/processed/car_sales_raw.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product       59 non-null     object
#  1   price         59 non-null     float64
#  2   branch        59 non-null     object
#  3   payment_type  59 non-null     object
#  4   date          59 non-null     object
#  5   profit        59 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 2.9+ KB
